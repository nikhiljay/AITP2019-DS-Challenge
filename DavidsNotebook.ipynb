# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
map_df = gpd.read_file('/scratch/brown/train54/AITP2019-DS-Challenge/tl_2013_18_cousub.shp')

indiana_stations = pd.read_csv('/scratch/brown/train54/AITP2019-DS-Challenge/gsod.stn.csv')
indiana_stations = indiana_stations[indiana_stations['state'] == 'IN']
indiana_lon = indiana_stations['longitude']
indiana_lat = indiana_stations['latitude']
map_df.plot()
plt.scatter(indiana_lon, indiana_lat, c='red')
plt.show()
